# %%
scores = ["100 Suckling, 98 Robert Parker, 98 Vinous",
"96+ Robert Parker, 97 Tim Atkin",
"100 James Suckling, 100 Robert Parker",
"99 Suckling, 98+ Robert Parker, 99 Vinous",
"100 James Suckling, 100 Robert Parker",
"100 Suckling, 98+ Parker",
"98 Suckling, 96 Robert Parker",
"99 Suckling, 97 Robert Parker",
"100 Suckling, 100 Robert Parker, 100 Vinous",
"100 Robert Parker, 100 James Suckling",
"98 Suckling,  97 Vinous",
"90-92 Parker, 92-93 Suckling, 94 WE",
"96-98+ Robert Parker, 96-97 James Suckling",
"94-96+ Robert Parker, 95-96 James Suckling",
"95 Robert Parker, 98 James Suckling",
"96 Robert Parker, 98 James Suckling",
"92 James Suckling",
"93-94 James Suckling",
"94 Suckling, 94 Robert Parker, 94 Vinous",
"95 Suckling,  96 Vinous",
"96 Suckling",
"95 James Suckling",
"94  Robert Parker, 93+ Neil Martin",
"91-93 Robert Parker, 94 James Suckling",
"93 James Suckling, 92-94 Vinous",
"99 Suckling, 97 Parker",
"99 James Suckling, 97+ Robert  Parker",
"93 James Suckling",
"97 James Suckling, 94 Robert Parker",
"96 Suckling, 94 Robert Parker, 96 Vinous",
"97 James Suckling, 95 Robert Parker",
"94 James Suckling",
"93 James Suckling",
"97 Suckling, 97 Robert Parker, 97 Vinous",
"99 James Suckling, 96 Robert Parker",
"97 James Suckling, 98 Jeb Dunuck",
"96 Suckling",
"100 Parker, 100 Suckling, 100 Vinous",
"94 James Suckling",
"96 James Suckling, 94+ Robert Parker",
"96 Suckling,  98 Vinous",
"96 James Suckling, 95 Robert Parker",
"96 James Suckling",
"97 James Suckling",
"96 James Suckling, 95 Robert Parker",
"97 Suckling, 96+ Robert Parker, 99 Vinous",
"96 Suckling, 96 Robert Parker, 96 Vinous",
"99 James Suckling",
"94 James Suckling, 93+ Robert Parker",
"96 James Suckling",
"98 Suckling, 96+ Robert Parker, 98 Vinous",
"95 Suckling, 95 Robert Parker, 95 Vinous",
"95 Suckling, 96 Robert Parker, 97 Vinous",
"96 Suckling, 94+ Robert Parker",
"96 Suckling, 97 Robert Parker, 96 Vinous",
" 98 James Suckling, 96 Robert Parker, 97 WS",
]

# %% [raw]
# import re

# %%
import re

# %%
scores
# Out:
# ['100 Suckling, 98 Robert Parker, 98 Vinous',
#  '96+ Robert Parker, 97 Tim Atkin',
#  '100 James Suckling, 100 Robert Parker',
#  '99 Suckling, 98+ Robert Parker, 99 Vinous',
#  '100 James Suckling, 100 Robert Parker',
#  '100 Suckling, 98+ Parker',
#  '98 Suckling, 96 Robert Parker',
#  '99 Suckling, 97 Robert Parker',
#  '100 Suckling, 100 Robert Parker, 100 Vinous',
#  '100 Robert Parker, 100 James Suckling',
#  '98 Suckling,  97 Vinous',
#  '90-92 Parker, 92-93 Suckling, 94 WE',
#  '96-98+ Robert Parker, 96-97 James Suckling',
#  '94-96+ Robert Parker, 95-96 James Suckling',
#  '95 Robert Parker, 98 James Suckling',
#  '96 Robert Parker, 98 James Suckling',
#  '92 James Suckling',
#  '93-94 James Suckling',
#  '94 Suckling, 94 Robert Parker, 94 Vinous',
#  '95 Suckling,  96 Vinous',
#  '96 Suckling',
#  '95 James Suckling',
#  '94  Robert Parker, 93+ Neil Martin',
#  '91-93 Robert Parker, 94 James Suckling',
#  '93 James Suckling, 92-94 Vinous',
#  '99 Suckling, 97 Parker',
#  '99 James Suckling, 97+ Robert  Parker',
#  '93 James Suckling',
#  '97 James Suckling, 94 Robert Parker',
#  '96 Suckling, 94 Robert Parker, 96 Vinous',
#  '97 James Suckling, 95 Robert Parker',
#  '94 James Suckling',
#  '93 James Suckling',
#  '97 Suckling, 97 Robert Parker, 97 Vinous',
#  '99 James Suckling, 96 Robert Parker',
#  '97 James Suckling, 98 Jeb Dunuck',
#  '96 Suckling',
#  '100 Parker, 100 Suckling, 100 Vinous',
#  '94 James Suckling',
#  '96 James Suckling, 94+ Robert Parker',
#  '96 Suckling,  98 Vinous',
#  '96 James Suckling, 95 Robert Parker',
#  '96 James Suckling',
#  '97 James Suckling',
#  '96 James Suckling, 95 Robert Parker',
#  '97 Suckling, 96+ Robert Parker, 99 Vinous',
#  '96 Suckling, 96 Robert Parker, 96 Vinous',
#  '99 James Suckling',
#  '94 James Suckling, 93+ Robert Parker',
#  '96 James Suckling',
#  '98 Suckling, 96+ Robert Parker, 98 Vinous',
#  '95 Suckling, 95 Robert Parker, 95 Vinous',
#  '95 Suckling, 96 Robert Parker, 97 Vinous',
#  '96 Suckling, 94+ Robert Parker',
#  '96 Suckling, 97 Robert Parker, 96 Vinous',
#  ' 98 James Suckling, 96 Robert Parker, 97 WS']

# %%
#  Robert Parker, James Suckling
# tabel = [{RP	JS	JR	AG	D	WS	LM	RVF}]
rp = []
js = []

# %%
for line in scores:
    line = line.replace(' ','').split(",")
    print(line)
    for score in line:
        if "Suckling" in score:
            js.append(re.findall("[0-9]{2}-*[0-9]*\+*", score)[0])
        else:
            js.append("")
        if "Parker" in score:
            rp.append(re.findall("[0-9]{2}-*[0-9]*\+*", score)[0])
        else:
            rp.append("")
# Out:
# ['100Suckling', '98RobertParker', '98Vinous']
# ['96+RobertParker', '97TimAtkin']
# ['100JamesSuckling', '100RobertParker']
# ['99Suckling', '98+RobertParker', '99Vinous']
# ['100JamesSuckling', '100RobertParker']
# ['100Suckling', '98+Parker']
# ['98Suckling', '96RobertParker']
# ['99Suckling', '97RobertParker']
# ['100Suckling', '100RobertParker', '100Vinous']
# ['100RobertParker', '100JamesSuckling']
# ['98Suckling', '97Vinous']
# ['90-92Parker', '92-93Suckling', '94WE']
# ['96-98+RobertParker', '96-97JamesSuckling']
# ['94-96+RobertParker', '95-96JamesSuckling']
# ['95RobertParker', '98JamesSuckling']
# ['96RobertParker', '98JamesSuckling']
# ['92JamesSuckling']
# ['93-94JamesSuckling']
# ['94Suckling', '94RobertParker', '94Vinous']
# ['95Suckling', '96Vinous']
# ['96Suckling']
# ['95JamesSuckling']
# ['94RobertParker', '93+NeilMartin']
# ['91-93RobertParker', '94JamesSuckling']
# ['93JamesSuckling', '92-94Vinous']
# ['99Suckling', '97Parker']
# ['99JamesSuckling', '97+RobertParker']
# ['93JamesSuckling']
# ['97JamesSuckling', '94RobertParker']
# ['96Suckling', '94RobertParker', '96Vinous']
# ['97JamesSuckling', '95RobertParker']
# ['94JamesSuckling']
# ['93JamesSuckling']
# ['97Suckling', '97RobertParker', '97Vinous']
# ['99JamesSuckling', '96RobertParker']
# ['97JamesSuckling', '98JebDunuck']
# ['96Suckling']
# ['100Parker', '100Suckling', '100Vinous']
# ['94JamesSuckling']
# ['96JamesSuckling', '94+RobertParker']
# ['96Suckling', '98Vinous']
# ['96JamesSuckling', '95RobertParker']
# ['96JamesSuckling']
# ['97JamesSuckling']
# ['96JamesSuckling', '95RobertParker']
# ['97Suckling', '96+RobertParker', '99Vinous']
# ['96Suckling', '96RobertParker', '96Vinous']
# ['99JamesSuckling']
# ['94JamesSuckling', '93+RobertParker']
# ['96JamesSuckling']
# ['98Suckling', '96+RobertParker', '98Vinous']
# ['95Suckling', '95RobertParker', '95Vinous']
# ['95Suckling', '96RobertParker', '97Vinous']
# ['96Suckling', '94+RobertParker']
# ['96Suckling', '97RobertParker', '96Vinous']
# ['98JamesSuckling', '96RobertParker', '97WS']

# %%
js
# Out:
# [['100'],
#  '',
#  '',
#  '',
#  '',
#  ['100'],
#  '',
#  ['99'],
#  '',
#  '',
#  ['100'],
#  '',
#  ['100'],
#  '',
#  ['98'],
#  '',
#  ['99'],
#  '',
#  ['100'],
#  '',
#  '',
#  '',
#  ['100'],
#  ['98'],
#  '',
#  '',
#  ['92-93'],
#  '',
#  '',
#  ['96-97'],
#  '',
#  ['95-96'],
#  '',
#  ['98'],
#  '',
#  ['98'],
#  ['92'],
#  ['93-94'],
#  ['94'],
#  '',
#  '',
#  ['95'],
#  '',
#  ['96'],
#  ['95'],
#  '',
#  '',
#  '',
#  ['94'],
#  ['93'],
#  '',
#  ['99'],
#  '',
#  ['99'],
#  '',
#  ['93'],
#  ['97'],
#  '',
#  ['96'],
#  '',
#  '',
#  ['97'],
#  '',
#  ['94'],
#  ['93'],
#  ['97'],
#  '',
#  '',
#  ['99'],
#  '',
#  ['97'],
#  '',
#  ['96'],
#  '',
#  ['100'],
#  '',
#  ['94'],
#  ['96'],
#  '',
#  ['96'],
#  '',
#  ['96'],
#  '',
#  ['96'],
#  ['97'],
#  ['96'],
#  '',
#  ['97'],
#  '',
#  '',
#  ['96'],
#  '',
#  '',
#  ['99'],
#  ['94'],
#  '',
#  ['96'],
#  ['98'],
#  '',
#  '',
#  ['95'],
#  '',
#  '',
#  ['95'],
#  '',
#  '',
#  ['96'],
#  '',
#  ['96'],
#  '',
#  '',
#  ['98'],
#  '',
#  '',
#  ['100'],
#  '',
#  '',
#  '',
#  '',
#  ['100'],
#  '',
#  ['99'],
#  '',
#  '',
#  ['100'],
#  '',
#  ['100'],
#  '',
#  ['98'],
#  '',
#  ['99'],
#  '',
#  ['100'],
#  '',
#  '',
#  '',
#  ['100'],
#  ['98'],
#  '',
#  '',
#  ['92-93'],
#  '',
#  '',
#  ['96-97'],
#  '',
#  ['95-96'],
#  '',
#  ['98'],
#  '',
#  ['98'],
#  ['92'],
#  ['93-94'],
#  ['94'],
#  '',
#  '',
#  ['95'],
#  '',
#  ['96'],
#  ['95'],
#  '',
#  '',
#  '',
#  ['94'],
#  ['93'],
#  '',
#  ['99'],
#  '',
#  ['99'],
#  '',
#  ['93'],
#  ['97'],
#  '',
#  ['96'],
#  '',
#  '',
#  ['97'],
#  '',
#  ['94'],
#  ['93'],
#  ['97'],
#  '',
#  '',
#  ['99'],
#  '',
#  ['97'],
#  '',
#  ['96'],
#  '',
#  ['100'],
#  '',
#  ['94'],
#  ['96'],
#  '',
#  ['96'],
#  '',
#  ['96'],
#  '',
#  ['96'],
#  ['97'],
#  ['96'],
#  '',
#  ['97'],
#  '',
#  '',
#  ['96'],
#  '',
#  '',
#  ['99'],
#  ['94'],
#  '',
#  ['96'],
#  ['98'],
#  '',
#  '',
#  ['95'],
#  '',
#  '',
#  ['95'],
#  '',
#  '',
#  ['96'],
#  '',
#  ['96'],
#  '',
#  '',
#  ['98'],
#  '',
#  '',
#  ['100'],
#  '',
#  '',
#  '',
#  '',
#  ['100'],
#  '',
#  ['99'],
#  '',
#  '',
#  ['100'],
#  '',
#  ['100'],
#  '',
#  ['98'],
#  '',
#  ['99'],
#  '',
#  ['100'],
#  '',
#  '',
#  '',
#  ['100'],
#  ['98'],
#  '',
#  '',
#  ['92-93'],
#  '',
#  '',
#  ['96-97'],
#  '',
#  ['95-96'],
#  '',
#  ['98'],
#  '',
#  ['98'],
#  ['92'],
#  ['93-94'],
#  ['94'],
#  '',
#  '',
#  ['95'],
#  '',
#  ['96'],
#  ['95'],
#  '',
#  '',
#  '',
#  ['94'],
#  ['93'],
#  '',
#  ['99'],
#  '',
#  ['99'],
#  '',
#  ['93'],
#  ['97'],
#  '',
#  ['96'],
#  '',
#  '',
#  ['97'],
#  '',
#  ['94'],
#  ['93'],
#  ['97'],
#  '',
#  '',
#  ['99'],
#  '',
#  ['97'],
#  '',
#  ['96'],
#  '',
#  ['100'],
#  '',
#  ['94'],
#  ['96'],
#  '',
#  ['96'],
#  '',
#  ['96'],
#  '',
#  ['96'],
#  ['97'],
#  ['96'],
#  '',
#  ['97'],
#  '',
#  '',
#  ['96'],
#  '',
#  '',
#  ['99'],
#  ['94'],
#  '',
#  ['96'],
#  ['98'],
#  '',
#  '',
#  ['95'],
#  '',
#  '',
#  ['95'],
#  '',
#  '',
#  ['96'],
#  '',
#  ['96'],
#  '',
#  '',
#  ['98'],
#  '',
#  '',
#  '100',
#  '',
#  '',
#  '',
#  '',
#  '100',
#  '',
#  '99',
#  '',
#  '',
#  '100',
#  '',
#  '100',
#  '',
#  '98',
#  '',
#  '99',
#  '',
#  '100',
#  '',
#  '',
#  '',
#  '100',
#  '98',
#  '',
#  '',
#  '92-93',
#  '',
#  '',
#  '96-97',
#  '',
#  '95-96',
#  '',
#  '98',
#  '',
#  '98',
#  '92',
#  '93-94',
#  '94',
#  '',
#  '',
#  '95',
#  '',
#  '96',
#  '95',
#  '',
#  '',
#  '',
#  '94',
#  '93',
#  '',
#  '99',
#  '',
#  '99',
#  '',
#  '93',
#  '97',
#  '',
#  '96',
#  '',
#  '',
#  '97',
#  '',
#  '94',
#  '93',
#  '97',
#  '',
#  '',
#  '99',
#  '',
#  '97',
#  '',
#  '96',
#  '',
#  '100',
#  '',
#  '94',
#  '96',
#  '',
#  '96',
#  '',
#  '96',
#  '',
#  '96',
#  '97',
#  '96',
#  '',
#  '97',
#  '',
#  '',
#  '96',
#  '',
#  '',
#  '99',
#  '94',
#  '',
#  '96',
#  '98',
#  '',
#  '',
#  '95',
#  '',
#  '',
#  '95',
#  '',
#  '',
#  '96',
#  '',
#  '96',
#  '',
#  '',
#  '98',
#  '',
#  '']
